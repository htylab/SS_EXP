# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import lena
from scipy.ndimage.filters import convolve

# %%
image = plt.imread('Lenna.png')
# image = lena() 和直接讀取lenna圖形的差別
# 呼叫的lena為(512,512)灰階圖像

# %% [markdown]
# # Q1 : 想想如何用與上面相似的辦法得到下面的結果。

# %%
plt.figure(figsize=[15,5])
plt.subplot(131)
plt.imshow(image[:,:,0], cmap=plt.cm.gray)
plt.colorbar()

plt.subplot(132)
plt.imshow(image[:,:,1], cmap=plt.cm.gray)
plt.colorbar()

plt.subplot(133)
plt.imshow(image[:,:,2], cmap=plt.cm.gray)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x112BE530>

# %% [markdown]
# # Q2 : 如何得到綠色和藍色遮罩的影像(如下圖)?

# %%
plt.figure(figsize=[15,5])
green_only = image.copy()
green_only[:,:,0] = 0
green_only[:,:,2] = 0
plt.subplot(121)
plt.imshow(green_only)

blue_only = image.copy()
blue_only[:,:,0] = 0
blue_only[:,:,1] = 0
plt.subplot(122)
plt.imshow(blue_only)

# %% [markdown]
# # Q3 : 請先創造出十字kernel，並用上述提及的mat得到右邊的結果。

# %%
plt.figure(figsize=[15,5])
mat = np.zeros((100,100))
mat[50,50] = 1
kernel = np.zeros((20, 20))
kernel[10, :] = 1
kernel[:, 10] = 1

plt.subplot(121)
plt.imshow(kernel, cmap=plt.cm.gray)

c = convolve(mat, kernel)
plt.subplot(122)
plt.imshow(c, cmap=plt.cm.gray)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x0C3C8760>

# %% [markdown]
# # Q4 : 如何能得到下面的結果圖?

# %%
image = lena()
src_image = image[:,:]

kernel_stamp = np.zeros((50,50))
kernel_stamp[np.arange(50), np.arange(50)] = 1.0
stamp = convolve(src_image, kernel_stamp)

plt.figure(figsize=[15,10])
plt.subplot(221)
plt.imshow(kernel_stamp, cmap=plt.cm.gray)
plt.subplot(222)
plt.imshow(stamp, cmap=plt.cm.gray)

kernel_stamp = np.zeros((50,50))
kernel_stamp[25,:] = 1.0
kernel_stamp[:,25] = 1.0
stamp = convolve(src_image, kernel_stamp)

plt.subplot(223)
plt.imshow(kernel_stamp, cmap=plt.cm.gray)
plt.subplot(224)
plt.imshow(stamp, cmap=plt.cm.gray)
